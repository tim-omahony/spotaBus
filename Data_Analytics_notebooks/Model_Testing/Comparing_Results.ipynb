# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
Lin_Reg = pd.read_csv("~/data/Model_Testing/Linear_Regression_Results_direction_split.csv")

# %%
Dec_tree = pd.read_csv("~/data/Model_Testing/Decision_Tree_Results.csv")
Dec_tree = Dec_tree.drop([Dec_tree.index[64]])
Dec_tree = Dec_tree.drop([Dec_tree.index[124]])

# %%
Random_Forest = pd.read_csv("~/data/Model_Testing/Random_Forest_Results_2.csv")
Random_Forest = Random_Forest.drop([Dec_tree.index[116]])
Random_Forest = Random_Forest.drop([Dec_tree.index[119]])

# %% [markdown]
# # Linear Regression

# %%
Lin_Reg
# Out:
#     Route  Direction  Mean_Absolute_Error_Train  Mean_Absolute_Error_Test  \
# 0      68          1                     10.675                    10.646
# 1      68          2                     12.086                    12.056
# 2     25B          1                     14.687                    14.678
# 3     25B          2                     17.200                    17.125
# 4     45A          1                     10.507                    10.556
# ..    ...        ...                        ...                       ...
# 247   77X          2                     16.594                    16.806
# 248   16D          1                     18.307            1709833030.097
# 249   33E          1                     10.043                    11.603
# 250   41D          1                     15.572           30533931171.529
# 251   41D          2                     15.438                    17.585
#
#      Mean_Percentage_Error  Mean_Absolute_Percentage_Error  \
# ...

# %%
problematic = Lin_Reg[Lin_Reg['Mean_Absolute_Error_Test']> 1000]

# %%
problematic
# Out:
#     Route  Direction  Mean_Absolute_Error_Train  Mean_Absolute_Error_Test  \
# 7     25A          2                     15.601               5652562.072
# 29    46A          2                     16.206                832259.987
# 42     41          1                     15.136               1199505.592
# 134   83A          1                     13.018                436099.496
# 156   84X          1                     17.298             100593887.822
# 220   51D          2                     20.156                  3722.140
# 241   40E          1                      7.337                734288.123
# 248   16D          1                     18.307            1709833030.097
# 250   41D          1                     15.572           30533931171.529
#
#      Mean_Percentage_Error  Mean_Absolute_Percentage_Error  \
# 7               -36234.376                       36234.576
# 29                3650.048                        3650.544
# ...

# %%
good = Lin_Reg[Lin_Reg['Mean_Absolute_Error_Test']< 1000]

# %%
good.describe()
# Out:
#        Direction  Mean_Absolute_Error_Train  Mean_Absolute_Error_Test  \
# count    243.000                    243.000                   243.000
# mean       1.514                     14.784                    14.848
# std        0.501                      4.653                     4.673
# min        1.000                      6.890                     6.616
# 25%        1.000                     12.037                    12.061
# 50%        2.000                     14.332                    14.407
# 75%        2.000                     16.335                    16.411
# max        2.000                     45.271                    45.047
#
#        Mean_Percentage_Error  Mean_Absolute_Percentage_Error  \
# count                243.000                         243.000
# mean                  -0.113                           0.290
# std                    0.038                           0.058
# min                   -0.357                           0.156
# ...

# %%
good.describe().to_csv('results_compared.csv', index=False, header=True , mode='a')

# %% [markdown]
# # Decision Tree

# %%
Dec_tree[Dec_tree['Route'] == '83A']
# Out:
#     Route  Direction  Mean_Absolute_Error_Train  Mean_Absolute_Error_Test  \
# 136   83A          1                     13.658                    14.153
# 137   83A          2                     12.242                    12.837
#
#      Mean_Percentage_Error  Mean_Absolute_Percentage_Error  \
# 136                 -0.127                           0.303
# 137                 -0.126                           0.293
#
#      Mean_Squared_Error  Root_Mean_Squared_Error  R_Square
# 136             416.518                   20.409     0.601
# 137             381.969                   19.544     0.674

# %%
Dec_tree.describe()
# Out:
#        Direction  Mean_Absolute_Error_Train  Mean_Absolute_Error_Test  \
# count    252.000                    252.000                   252.000
# mean       1.504                     14.569                    15.606
# std        0.501                      4.158                     4.629
# min        1.000                      6.521                     7.104
# 25%        1.000                     12.124                    12.928
# 50%        2.000                     14.438                    15.178
# 75%        2.000                     16.111                    17.024
# max        2.000                     41.690                    46.578
#
#        Mean_Percentage_Error  Mean_Absolute_Percentage_Error  \
# count                252.000                         252.000
# mean                  -0.140                           0.309
# std                    0.051                           0.067
# min                   -0.405                           0.160
# ...

# %%
Dec_tree.describe().to_csv('results_compared.csv', index=False, header=True , mode='a')

# %% [markdown]
# # Random Forest

# %%
Random_Forest
# Out:
#     Route  Direction  Mean_Absolute_Error_Train  Mean_Absolute_Error_Test  \
# 0      68          1                      8.960                     9.620
# 1      68          2                     10.131                    10.860
# 2     25B          1                     12.096                    13.253
# 3     25B          2                     13.661                    14.865
# 4     45A          1                      8.920                     9.748
# ..    ...        ...                        ...                       ...
# 249   77X          2                     13.655                    16.398
# 250   16D          1                     15.007                    18.943
# 251   33E          1                     10.158                    12.551
# 252   41D          1                     14.139                    18.132
# 253   41D          2                     15.923                    18.055
#
#      Mean_Percentage_Error  Mean_Absolute_Percentage_Error  \
# ...

# %%
Random_Forest.describe()
# Out:
#        Direction  Mean_Absolute_Error_Train  Mean_Absolute_Error_Test  \
# count    252.000                    252.000                   252.000
# mean       1.508                     11.872                    13.783
# std        0.501                      3.488                     4.377
# min        1.000                      5.516                     6.590
# 25%        1.000                      9.599                    11.061
# 50%        2.000                     11.532                    13.208
# 75%        2.000                     13.536                    15.402
# max        2.000                     34.765                    43.839
#
#        Mean_Percentage_Error  Mean_Absolute_Percentage_Error  \
# count                252.000                         252.000
# mean                  -0.111                           0.258
# std                    0.037                           0.051
# min                   -0.353                           0.147
# ...

# %%
Random_Forest.describe().to_csv('results_compared.csv', index=False, header=True , mode='a')
